# %%
# from getpass import getpass
# repo_url = f"https://REDACTED-CREDENTIAL@github.com/Nikelroid/Adversarial-CoEvolution.git"

# !git clone $repo_url

# %%
# %cd Adversarial-CoEvolution

# %%
# !wget -c https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh

# # Make it executable
# !chmod +x Miniconda3-latest-Linux-x86_64.sh

# # Run the installer (silent mode, installs to /usr/local/)
# !bash ./Miniconda3-latest-Linux-x86_64.sh -b -p $HOME/miniconda

# %%
# # Initialize conda
# import sys
# import os
# sys.path.append(f"{os.environ['HOME']}/miniconda/lib/python3.10/site-packages")

# %%
import os
os.environ["PATH"] = f"{os.environ['HOME']}/miniconda/bin:" + os.environ["PATH"]

# %%
# !conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/main
# !conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/r

# %%
#!conda env create -f environment.yml

# %%
# !source activate marl

# %%
import os
os.environ['WANDB_API_KEY'] = "af7295dc60b36717e416fd0def548adf8c0a0528"
print("✓ W&B API key configured!")

# %%
os.environ['HF_TOKEN'] = "REDACTED-CREDENTIAL"
print("✓ HugginFace API key configured!")

# %%
# !git fetch origin

# %%
# !git checkout -f final-part

# %%
# !git branch

# %%
# !pip install -r requirements.txt

# %%
#!git reset --hard origin/main

# %%
# !git pull

# %%
#rm -r artifacts/models/ppo_gin_rummy/curriculum_pool

# %%
# !conda run -n marl python -u ppo_train.py \
    --train \
    --wandb-run-name "PPO-Final-Short-Term-V4" \
    --num-env 48 \
    --learning-rate 3e-4 \
    --batch-size 64 \
    --ent-coef 0.01 \
    --reward-system short \
    --timesteps 10000000 \
    --save-path "./artifacts/models/ppo_gin_short-term" \
    --game-length 4

# %%
# !python main.py \
    --player1 ppo --player1-name "DAgger-Agent" \
    --player2 random --player2-name "Random-Opponent" \
    --model ./artifacts/models/dagger/final_model \
    --tournament --num-games 10

# %%
# !conda run -n marl python dagger_train.py --timesteps 100000 --episodes-per-iter 50 --epochs 4

# %%
#!conda run -n marl python test_curriculum_setup.py

# %%
#!conda run -n marl python -u main.py --player1 ppo --player2 random --tournament --num-games 10000 --model ./artifacts/models/ppo_gin_rummy/ppo_gin_rummy_final_knock

# %%
#!conda run -n marl python llm_test.py --testnumber 4 --model "gpt-oss:20b" --trial 5
